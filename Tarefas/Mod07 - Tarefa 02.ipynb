# %% [markdown]
# # Módulo 07 - Tarefa 02
#
# #### 1) Carregue a base e garanta que a base está como deveria.
#
# Considere a base que você ajustou na lição passada. Carregue-a. Caso ainda haja alguma pendência, ajuste - lembre-se de que o scikitlearn não recebe variáveis em formato string, somente numéricas, e não aceita '*missings*'.
#
# - Separe 70% da base para treinamento e 30% para validação. Cada uma dessas partes terá dois objetos, um armazenando a variável resposta ```mau```e outro armazenando as variáveis explicativas (lembrando: sem variáveis string, já com as dummies).

# %%
# %matplotlib widget
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('df_dummies.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              16650 non-null  int64
#  1   qtd_filhos                              16650 non-null  int64
#  2   idade                                   16650 non-null  float64
#  3   tempo_emprego                           16650 non-null  float64
#  4   possui_celular                          16650 non-null  int64
#  5   possui_fone_comercial                   16650 non-null  int64
#  6   possui_fone                             16650 non-null  int64
#  7   possui_email                            16650 non-null  int64
#  8   qt_pessoas_residencia                   16650 non-null  float64
#  9   mau                                     16650 non-null  bool
#  10  sexo_F                                  16650 non-null  int64
#  11  sexo_M                                  16650 non-null  int64
#  12  posse_de_veiculo_N                      16650 non-null  int64
#  13  posse_de_veiculo_Y                      16650 non-null  int64
#  14  posse_de_imovel_N                       16650 non-null  int64
#  15  posse_de_imovel_Y                       16650 non-null  int64
#  16  tipo_renda_Commercial associate         16650 non-null  int64
#  17  tipo_renda_Pensioner                    16650 non-null  int64
#  18  tipo_renda_State servant                16650 non-null  int64
#  19  tipo_renda_Student                      16650 non-null  int64
#  20  tipo_renda_Working                      16650 non-null  int64
#  21  educacao_Academic degree                16650 non-null  int64
#  22  educacao_Higher education               16650 non-null  int64
#  23  educacao_Incomplete higher              16650 non-null  int64
#  24  educacao_Lower secondary                16650 non-null  int64
#  25  educacao_Secondary / secondary special  16650 non-null  int64
#  26  estado_civil_Civil marriage             16650 non-null  int64
#  27  estado_civil_Married                    16650 non-null  int64
#  28  estado_civil_Separated                  16650 non-null  int64
#  29  estado_civil_Single / not married       16650 non-null  int64
#  30  estado_civil_Widow                      16650 non-null  int64
#  31  tipo_residencia_Co-op apartment         16650 non-null  int64
#  32  tipo_residencia_House / apartment       16650 non-null  int64
#  33  tipo_residencia_Municipal apartment     16650 non-null  int64
#  34  tipo_residencia_Office apartment        16650 non-null  int64
#  35  tipo_residencia_Rented apartment        16650 non-null  int64
#  36  tipo_residencia_With parents            16650 non-null  int64
# dtypes: bool(1), float64(3), int64(33)
# memory usage: 4.6 MB

# %% [markdown]
# #### 2) Vamos para o modelo:
#
# 1. Defina um objeto com a função da árvore de decisão vista em aula.
# 2. Treine o modelo com os dados que você separou para treinamento.
# 3. Visualize a árvore. Talvez você queira aumentar um pouco a figura.
# 4. Produza uma visualização da matriz de classificação (ou matriz de confusão) - coloque os rótulos como "aprovados" e "reprovados" - pois afinal de contas, são essas as decisões que se podem tomar com propostas de crédito.
# 5. Calcule a acurácia na base de treinamento

# %%
#1
clf = DecisionTreeClassifier()

# %%
#2
y = df.mau
X = df.drop('mau',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#3
plt.figure(figsize=(25, 10))
plot_tree(clf,
          filled=True,
          class_names=['Reprovados', 'Aprovados'])
# Out:
# [Text(0.5743870489160263, 0.9807692307692307, 'x[0] <= 16470.0\ngini = 0.044\nsamples = 11655\nvalue = [11392, 263]\nclass = Reprovados'),
#  Text(0.5699962695526893, 0.9423076923076923, 'x[3] <= 2.848\ngini = 0.024\nsamples = 11530\nvalue = [11392, 138]\nclass = Reprovados'),
#  Text(0.2637812156970362, 0.9038461538461539, 'x[2] <= 30.175\ngini = 0.034\nsamples = 4222\nvalue = [4149, 73]\nclass = Reprovados'),
#  Text(0.10949506037321624, 0.8653846153846154, 'x[2] <= 30.137\ngini = 0.08\nsamples = 430\nvalue = [412, 18]\nclass = Reprovados'),
#  Text(0.09522502744237102, 0.8269230769230769, 'x[0] <= 13411.0\ngini = 0.068\nsamples = 423\nvalue = [408, 15]\nclass = Reprovados'),
#  Text(0.07985729967069155, 0.7884615384615384, 'x[2] <= 28.567\ngini = 0.03\nsamples = 331\nvalue = [326, 5]\nclass = Reprovados'),
#  Text(0.07546652030735455, 0.75, 'gini = 0.0\nsamples = 235\nvalue = [235, 0]\nclass = Reprovados'),
#  Text(0.08424807903402853, 0.75, 'x[2] <= 28.595\ngini = 0.099\nsamples = 96\nvalue = [91, 5]\nclass = Reprovados'),
#  Text(0.07985729967069155, 0.7115384615384616, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.08863885839736553, 0.7115384615384616, 'x[2] <= 28.777\ngini = 0.081\nsamples = 95\nvalue = [91, 4]\nclass = Reprovados'),
#  Text(0.07985729967069155, 0.6730769230769231, 'x[0] <= 11649.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = Reprovados'),
#  Text(0.07546652030735455, 0.6346153846153846, 'x[2] <= 28.622\ngini = 0.124\nsamples = 15\nvalue = [14, 1]\nclass = Reprovados'),
#  Text(0.07107574094401756, 0.5961538461538461, 'x[0] <= 5270.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.06668496158068057, 0.5576923076923077, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.07546652030735455, 0.5576923076923077, 'x[0] <= 5271.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.07107574094401756, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.07985729967069155, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.07985729967069155, 0.5961538461538461, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Reprovados'),
#  Text(0.08424807903402853, 0.6346153846153846, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.09742041712403952, 0.6730769230769231, 'x[3] <= 0.679\ngini = 0.025\nsamples = 78\nvalue = [77, 1]\nclass = Reprovados'),
#  Text(0.09302963776070253, 0.6346153846153846, 'x[3] <= 0.575\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Reprovados'),
#  Text(0.08863885839736553, 0.5961538461538461, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Reprovados'),
#  Text(0.09742041712403952, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.1018111964873765, 0.6346153846153846, 'gini = 0.0\nsamples = 64\nvalue = [64, 0]\nclass = Reprovados'),
#  Text(0.1105927552140505, 0.7884615384615384, 'x[0] <= 13462.5\ngini = 0.194\nsamples = 92\nvalue = [82, 10]\nclass = Reprovados'),
#  Text(0.1062019758507135, 0.75, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Aprovados'),
#  Text(0.11498353457738748, 0.75, 'x[3] <= 0.526\ngini = 0.068\nsamples = 85\nvalue = [82, 3]\nclass = Reprovados'),
#  Text(0.1105927552140505, 0.7115384615384616, 'x[31] <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]\nclass = Reprovados'),
#  Text(0.1062019758507135, 0.6730769230769231, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.11498353457738748, 0.6730769230769231, 'x[7] <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]\nclass = Reprovados'),
#  Text(0.1105927552140505, 0.6346153846153846, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Reprovados'),
#  Text(0.11937431394072448, 0.6346153846153846, 'x[0] <= 15721.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.11498353457738748, 0.5961538461538461, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.12376509330406148, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.11937431394072448, 0.7115384615384616, 'gini = 0.0\nsamples = 66\nvalue = [66, 0]\nclass = Reprovados'),
#  Text(0.12376509330406148, 0.8269230769230769, 'x[0] <= 932.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Reprovados'),
#  Text(0.11937431394072448, 0.7884615384615384, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.12815587266739847, 0.7884615384615384, 'x[0] <= 933.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = Reprovados'),
#  Text(0.12376509330406148, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.13254665203073546, 0.75, 'x[0] <= 935.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Reprovados'),
#  Text(0.12815587266739847, 0.7115384615384616, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.13693743139407244, 0.7115384615384616, 'x[1] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Reprovados'),
#  Text(0.13254665203073546, 0.6730769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.14132821075740945, 0.6730769230769231, 'x[0] <= 14918.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.13693743139407244, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.14571899012074643, 0.6346153846153846, 'x[0] <= 14919.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.14132821075740945, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.15010976948408342, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.4180673710208562, 0.8653846153846154, 'x[3] <= 2.845\ngini = 0.029\nsamples = 3792\nvalue = [3737, 55]\nclass = Reprovados'),
#  Text(0.3890985181119649, 0.8269230769230769, 'x[27] <= 0.5\ngini = 0.028\nsamples = 3788\nvalue = [3734, 54]\nclass = Reprovados'),
#  Text(0.3531147091108672, 0.7884615384615384, 'x[3] <= 2.742\ngini = 0.025\nsamples = 3569\nvalue = [3524, 45]\nclass = Reprovados'),
#  Text(0.31627332601536773, 0.75, 'x[8] <= 4.5\ngini = 0.024\nsamples = 3524\nvalue = [3482, 42]\nclass = Reprovados'),
#  Text(0.27332601536772777, 0.7115384615384616, 'x[29] <= 0.5\ngini = 0.023\nsamples = 3488\nvalue = [3448, 40]\nclass = Reprovados'),
#  Text(0.20499451152579584, 0.6730769230769231, 'x[0] <= 12385.0\ngini = 0.02\nsamples = 3179\nvalue = [3147, 32]\nclass = Reprovados'),
#  Text(0.1632821075740944, 0.6346153846153846, 'x[3] <= 1.607\ngini = 0.016\nsamples = 2372\nvalue = [2353, 19]\nclass = Reprovados'),
#  Text(0.1588913282107574, 0.5961538461538461, 'x[3] <= 1.601\ngini = 0.02\nsamples = 1857\nvalue = [1838, 19]\nclass = Reprovados'),
#  Text(0.14407244785949505, 0.5576923076923077, 'x[2] <= 60.167\ngini = 0.019\nsamples = 1851\nvalue = [1833, 18]\nclass = Reprovados'),
#  Text(0.12760702524698134, 0.5192307692307693, 'x[2] <= 60.075\ngini = 0.026\nsamples = 1211\nvalue = [1195, 16]\nclass = Reprovados'),
#  Text(0.11663007683863885, 0.4807692307692308, 'x[2] <= 59.801\ngini = 0.021\nsamples = 1204\nvalue = [1191, 13]\nclass = Reprovados'),
#  Text(0.10784851811196487, 0.4423076923076923, 'x[2] <= 57.207\ngini = 0.019\nsamples = 1165\nvalue = [1154, 11]\nclass = Reprovados'),
#  Text(0.10345773874862788, 0.40384615384615385, 'x[2] <= 57.17\ngini = 0.024\nsamples = 915\nvalue = [904, 11]\nclass = Reprovados'),
#  Text(0.07958287596048298, 0.36538461538461536, 'x[3] <= 0.544\ngini = 0.022\nsamples = 912\nvalue = [902, 10]\nclass = Reprovados'),
#  Text(0.04500548847420417, 0.3269230769230769, 'x[3] <= 0.501\ngini = 0.032\nsamples = 437\nvalue = [430, 7]\nclass = Reprovados'),
#  Text(0.024149286498353458, 0.28846153846153844, 'x[1] <= 0.5\ngini = 0.019\nsamples = 421\nvalue = [417, 4]\nclass = Reprovados'),
#  Text(0.008781558726673985, 0.25, 'x[0] <= 11025.5\ngini = 0.006\nsamples = 308\nvalue = [307, 1]\nclass = Reprovados'),
#  Text(0.0043907793633369925, 0.21153846153846154, 'gini = 0.0\nsamples = 285\nvalue = [285, 0]\nclass = Reprovados'),
#  Text(0.013172338090010977, 0.21153846153846154, 'x[0] <= 11028.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = Reprovados'),
#  Text(0.008781558726673985, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.01756311745334797, 0.17307692307692307, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Reprovados'),
#  Text(0.03951701427003293, 0.25, 'x[26] <= 0.5\ngini = 0.052\nsamples = 113\nvalue = [110, 3]\nclass = Reprovados'),
#  Text(0.030735455543358946, 0.21153846153846154, 'x[21] <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Reprovados'),
#  Text(0.026344676180021953, 0.17307692307692307, 'x[14] <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Reprovados'),
#  Text(0.021953896816684963, 0.1346153846153846, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.030735455543358946, 0.1346153846153846, 'x[25] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Reprovados'),
#  Text(0.026344676180021953, 0.09615384615384616, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.03512623490669594, 0.09615384615384616, 'x[3] <= -500.141\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.030735455543358946, 0.057692307692307696, 'x[0] <= 4302.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.026344676180021953, 0.019230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.03512623490669594, 0.019230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.03951701427003293, 0.057692307692307696, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.03512623490669594, 0.17307692307692307, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.048298572996706916, 0.21153846153846154, 'x[0] <= 1950.5\ngini = 0.02\nsamples = 101\nvalue = [100, 1]\nclass = Reprovados'),
#  Text(0.043907793633369926, 0.17307692307692307, 'x[0] <= 1604.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.03951701427003293, 0.1346153846153846, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.048298572996706916, 0.1346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.052689352360043906, 0.17307692307692307, 'gini = 0.0\nsamples = 96\nvalue = [96, 0]\nclass = Reprovados'),
#  Text(0.06586169045005488, 0.28846153846153844, 'x[24] <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = Reprovados'),
#  Text(0.06147091108671789, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.07025246981339188, 0.25, 'x[1] <= 1.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]\nclass = Reprovados'),
#  Text(0.06586169045005488, 0.21153846153846154, 'x[0] <= 1470.0\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Reprovados'),
#  Text(0.06147091108671789, 0.17307692307692307, 'x[0] <= 1083.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.0570801317233809, 0.1346153846153846, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.06586169045005488, 0.1346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.07025246981339188, 0.17307692307692307, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Reprovados'),
#  Text(0.07464324917672886, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.1141602634467618, 0.3269230769230769, 'x[35] <= 0.5\ngini = 0.013\nsamples = 475\nvalue = [472, 3]\nclass = Reprovados'),
#  Text(0.10098792535675083, 0.28846153846153844, 'x[3] <= 1.512\ngini = 0.009\nsamples = 452\nvalue = [450, 2]\nclass = Reprovados'),
#  Text(0.08781558726673985, 0.25, 'x[5] <= 0.5\ngini = 0.005\nsamples = 414\nvalue = [413, 1]\nclass = Reprovados'),
#  Text(0.08342480790340286, 0.21153846153846154, 'gini = 0.0\nsamples = 322\nvalue = [322, 0]\nclass = Reprovados'),
#  Text(0.09220636663007684, 0.21153846153846154, 'x[0] <= 3679.5\ngini = 0.022\nsamples = 92\nvalue = [91, 1]\nclass = Reprovados'),
#  Text(0.08781558726673985, 0.17307692307692307, 'x[0] <= 3657.0\ngini = 0.077\nsamples = 25\nvalue = [24, 1]\nclass = Reprovados'),
#  Text(0.08342480790340286, 0.1346153846153846, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Reprovados'),
#  Text(0.09220636663007684, 0.1346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.09659714599341383, 0.17307692307692307, 'gini = 0.0\nsamples = 67\nvalue = [67, 0]\nclass = Reprovados'),
#  Text(0.1141602634467618, 0.25, 'x[3] <= 1.516\ngini = 0.051\nsamples = 38\nvalue = [37, 1]\nclass = Reprovados'),
#  Text(0.10976948408342481, 0.21153846153846154, 'x[0] <= 7544.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.10537870472008781, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.1141602634467618, 0.17307692307692307, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.11855104281009879, 0.21153846153846154, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]\nclass = Reprovados'),
#  Text(0.12733260153677278, 0.28846153846153844, 'x[5] <= 0.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = Reprovados'),
#  Text(0.12294182217343579, 0.25, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]\nclass = Reprovados'),
#  Text(0.13172338090010977, 0.25, 'x[3] <= 1.095\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.12733260153677278, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.13611416026344675, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.12733260153677278, 0.36538461538461536, 'x[0] <= 6849.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.12294182217343579, 0.3269230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.13172338090010977, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.11223929747530187, 0.40384615384615385, 'gini = 0.0\nsamples = 250\nvalue = [250, 0]\nclass = Reprovados'),
#  Text(0.12541163556531285, 0.4423076923076923, 'x[2] <= 59.815\ngini = 0.097\nsamples = 39\nvalue = [37, 2]\nclass = Reprovados'),
#  Text(0.12102085620197585, 0.40384615384615385, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.12980241492864983, 0.40384615384615385, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]\nclass = Reprovados'),
#  Text(0.13858397365532382, 0.4807692307692308, 'x[0] <= 7493.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Reprovados'),
#  Text(0.13419319429198684, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.1429747530186608, 0.4423076923076923, 'x[2] <= 60.103\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Reprovados'),
#  Text(0.13858397365532382, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.14736553238199782, 0.40384615384615385, 'x[21] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.1429747530186608, 0.36538461538461536, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.1517563117453348, 0.36538461538461536, 'x[0] <= 7495.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.14736553238199782, 0.3269230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.15614709110867178, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.1605378704720088, 0.5192307692307693, 'x[28] <= 0.5\ngini = 0.006\nsamples = 640\nvalue = [638, 2]\nclass = Reprovados'),
#  Text(0.15614709110867178, 0.4807692307692308, 'gini = 0.0\nsamples = 543\nvalue = [543, 0]\nclass = Reprovados'),
#  Text(0.16492864983534578, 0.4807692307692308, 'x[0] <= 5024.5\ngini = 0.04\nsamples = 97\nvalue = [95, 2]\nclass = Reprovados'),
#  Text(0.1605378704720088, 0.4423076923076923, 'x[0] <= 4726.0\ngini = 0.142\nsamples = 26\nvalue = [24, 2]\nclass = Reprovados'),
#  Text(0.15614709110867178, 0.40384615384615385, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]\nclass = Reprovados'),
#  Text(0.16492864983534578, 0.40384615384615385, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.16931942919868276, 0.4423076923076923, 'gini = 0.0\nsamples = 71\nvalue = [71, 0]\nclass = Reprovados'),
#  Text(0.17371020856201977, 0.5576923076923077, 'x[0] <= 327.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.16931942919868276, 0.5192307692307693, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.17810098792535675, 0.5192307692307693, 'x[0] <= 329.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.17371020856201977, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.18249176728869373, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.1676728869374314, 0.5961538461538461, 'gini = 0.0\nsamples = 515\nvalue = [515, 0]\nclass = Reprovados'),
#  Text(0.24670691547749726, 0.6346153846153846, 'x[0] <= 12388.5\ngini = 0.032\nsamples = 807\nvalue = [794, 13]\nclass = Reprovados'),
#  Text(0.24231613611416025, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.2510976948408343, 0.5961538461538461, 'x[3] <= 2.356\ngini = 0.029\nsamples = 806\nvalue = [794, 12]\nclass = Reprovados'),
#  Text(0.2231064763995609, 0.5576923076923077, 'x[2] <= 62.052\ngini = 0.021\nsamples = 761\nvalue = [753, 8]\nclass = Reprovados'),
#  Text(0.20005488474204172, 0.5192307692307693, 'x[23] <= 0.5\ngini = 0.012\nsamples = 637\nvalue = [633, 4]\nclass = Reprovados'),
#  Text(0.19127332601536773, 0.4807692307692308, 'x[2] <= 55.053\ngini = 0.01\nsamples = 616\nvalue = [613, 3]\nclass = Reprovados'),
#  Text(0.18688254665203075, 0.4423076923076923, 'gini = 0.0\nsamples = 399\nvalue = [399, 0]\nclass = Reprovados'),
#  Text(0.1956641053787047, 0.4423076923076923, 'x[2] <= 55.104\ngini = 0.027\nsamples = 217\nvalue = [214, 3]\nclass = Reprovados'),
#  Text(0.19127332601536773, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.20005488474204172, 0.40384615384615385, 'x[2] <= 57.449\ngini = 0.018\nsamples = 216\nvalue = [214, 2]\nclass = Reprovados'),
#  Text(0.1956641053787047, 0.36538461538461536, 'x[2] <= 57.101\ngini = 0.062\nsamples = 62\nvalue = [60, 2]\nclass = Reprovados'),
#  Text(0.19127332601536773, 0.3269230769230769, 'gini = 0.0\nsamples = 56\nvalue = [56, 0]\nclass = Reprovados'),
#  Text(0.20005488474204172, 0.3269230769230769, 'x[0] <= 12898.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Reprovados'),
#  Text(0.1956641053787047, 0.28846153846153844, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.2044456641053787, 0.28846153846153844, 'x[2] <= 57.115\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.20005488474204172, 0.25, 'x[0] <= 13725.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.1956641053787047, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.2044456641053787, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.2088364434687157, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.2044456641053787, 0.36538461538461536, 'gini = 0.0\nsamples = 154\nvalue = [154, 0]\nclass = Reprovados'),
#  Text(0.2088364434687157, 0.4807692307692308, 'x[3] <= 1.449\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Reprovados'),
#  Text(0.2044456641053787, 0.4423076923076923, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = Reprovados'),
#  Text(0.2132272228320527, 0.4423076923076923, 'x[0] <= 13865.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.2088364434687157, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.21761800219538968, 0.40384615384615385, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.24615806805708013, 0.5192307692307693, 'x[2] <= 62.252\ngini = 0.062\nsamples = 124\nvalue = [120, 4]\nclass = Reprovados'),
#  Text(0.23518111964873764, 0.4807692307692308, 'x[2] <= 62.218\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Reprovados'),
#  Text(0.23079034028540066, 0.4423076923076923, 'x[2] <= 62.115\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.22639956092206368, 0.40384615384615385, 'x[11] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.22200878155872666, 0.36538461538461536, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.23079034028540066, 0.36538461538461536, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.23518111964873764, 0.40384615384615385, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.23957189901207465, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.25713501646542264, 0.4807692307692308, 'x[25] <= 0.5\ngini = 0.034\nsamples = 117\nvalue = [115, 2]\nclass = Reprovados'),
#  Text(0.24835345773874862, 0.4423076923076923, 'x[2] <= 65.118\ngini = 0.018\nsamples = 111\nvalue = [110, 1]\nclass = Reprovados'),
#  Text(0.24396267837541163, 0.40384615384615385, 'gini = 0.0\nsamples = 97\nvalue = [97, 0]\nclass = Reprovados'),
#  Text(0.2527442371020856, 0.40384615384615385, 'x[2] <= 65.444\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Reprovados'),
#  Text(0.24835345773874862, 0.36538461538461536, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.25713501646542264, 0.36538461538461536, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Reprovados'),
#  Text(0.2659165751920966, 0.4423076923076923, 'x[16] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.2615257958287596, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.2703073545554336, 0.40384615384615385, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.27908891328210755, 0.5576923076923077, 'x[2] <= 51.188\ngini = 0.162\nsamples = 45\nvalue = [41, 4]\nclass = Reprovados'),
#  Text(0.27469813391877057, 0.5192307692307693, 'x[8] <= 1.5\ngini = 0.127\nsamples = 44\nvalue = [41, 3]\nclass = Reprovados'),
#  Text(0.2703073545554336, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.27908891328210755, 0.4807692307692308, 'x[8] <= 2.5\ngini = 0.089\nsamples = 43\nvalue = [41, 2]\nclass = Reprovados'),
#  Text(0.27469813391877057, 0.4423076923076923, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]\nclass = Reprovados'),
#  Text(0.2834796926454446, 0.4423076923076923, 'x[6] <= 0.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Reprovados'),
#  Text(0.27908891328210755, 0.40384615384615385, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.2878704720087816, 0.40384615384615385, 'x[0] <= 15161.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Reprovados'),
#  Text(0.2834796926454446, 0.36538461538461536, 'x[15] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Aprovados'),
#  Text(0.27908891328210755, 0.3269230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.2878704720087816, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.29226125137211856, 0.36538461538461536, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.2834796926454446, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.3416575192096597, 0.6730769230769231, 'x[3] <= 1.355\ngini = 0.05\nsamples = 309\nvalue = [301, 8]\nclass = Reprovados'),
#  Text(0.33287596048298573, 0.6346153846153846, 'x[2] <= 58.514\ngini = 0.033\nsamples = 302\nvalue = [297, 5]\nclass = Reprovados'),
#  Text(0.32848518111964875, 0.5961538461538461, 'gini = 0.0\nsamples = 97\nvalue = [97, 0]\nclass = Reprovados'),
#  Text(0.3372667398463227, 0.5961538461538461, 'x[2] <= 58.56\ngini = 0.048\nsamples = 205\nvalue = [200, 5]\nclass = Reprovados'),
#  Text(0.33287596048298573, 0.5576923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.3416575192096597, 0.5576923076923077, 'x[7] <= 0.5\ngini = 0.038\nsamples = 204\nvalue = [200, 4]\nclass = Reprovados'),
#  Text(0.32958287596048297, 0.5192307692307693, 'x[14] <= 0.5\ngini = 0.03\nsamples = 196\nvalue = [193, 3]\nclass = Reprovados'),
#  Text(0.3186059275521405, 0.4807692307692308, 'x[2] <= 65.462\ngini = 0.083\nsamples = 46\nvalue = [44, 2]\nclass = Reprovados'),
#  Text(0.30982436882546655, 0.4423076923076923, 'x[0] <= 5448.5\ngini = 0.049\nsamples = 40\nvalue = [39, 1]\nclass = Reprovados'),
#  Text(0.3054335894621295, 0.40384615384615385, 'x[2] <= 60.614\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Reprovados'),
#  Text(0.3010428100987925, 0.36538461538461536, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Reprovados'),
#  Text(0.30982436882546655, 0.36538461538461536, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.31421514818880353, 0.40384615384615385, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = Reprovados'),
#  Text(0.3273874862788145, 0.4423076923076923, 'x[2] <= 65.907\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.3229967069154775, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.33177826564215146, 0.40384615384615385, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.3405598243688255, 0.4807692307692308, 'x[2] <= 66.612\ngini = 0.013\nsamples = 150\nvalue = [149, 1]\nclass = Reprovados'),
#  Text(0.3361690450054885, 0.4423076923076923, 'gini = 0.0\nsamples = 120\nvalue = [120, 0]\nclass = Reprovados'),
#  Text(0.34495060373216246, 0.4423076923076923, 'x[2] <= 66.663\ngini = 0.064\nsamples = 30\nvalue = [29, 1]\nclass = Reprovados'),
#  Text(0.3405598243688255, 0.40384615384615385, 'x[0] <= 7133.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.3361690450054885, 0.36538461538461536, 'x[0] <= 7131.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.33177826564215146, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.3405598243688255, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.34495060373216246, 0.36538461538461536, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.34934138309549945, 0.40384615384615385, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Reprovados'),
#  Text(0.35373216245883643, 0.5192307692307693, 'x[11] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Reprovados'),
#  Text(0.34934138309549945, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.3581229418221734, 0.4807692307692308, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.3504390779363337, 0.6346153846153846, 'x[13] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Reprovados'),
#  Text(0.3460482985729967, 0.5961538461538461, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.3548298572996707, 0.5961538461538461, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Aprovados'),
#  Text(0.3592206366630077, 0.7115384615384616, 'x[0] <= 11833.5\ngini = 0.105\nsamples = 36\nvalue = [34, 2]\nclass = Reprovados'),
#  Text(0.3548298572996707, 0.6730769230769231, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = Reprovados'),
#  Text(0.36361141602634467, 0.6730769230769231, 'x[0] <= 13127.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Reprovados'),
#  Text(0.3592206366630077, 0.6346153846153846, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.36800219538968165, 0.6346153846153846, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.3899560922063666, 0.75, 'x[3] <= 2.747\ngini = 0.124\nsamples = 45\nvalue = [42, 3]\nclass = Reprovados'),
#  Text(0.38556531284302964, 0.7115384615384616, 'x[0] <= 850.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Aprovados'),
#  Text(0.38117453347969266, 0.6730769230769231, 'x[0] <= 849.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.3767837541163557, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.38556531284302964, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.3899560922063666, 0.6730769230769231, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.3943468715697036, 0.7115384615384616, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]\nclass = Reprovados'),
#  Text(0.42508232711306254, 0.7884615384615384, 'x[23] <= 0.5\ngini = 0.079\nsamples = 219\nvalue = [210, 9]\nclass = Reprovados'),
#  Text(0.42069154774972556, 0.75, 'x[2] <= 66.992\ngini = 0.071\nsamples = 218\nvalue = [210, 8]\nclass = Reprovados'),
#  Text(0.4163007683863886, 0.7115384615384616, 'x[0] <= 13239.0\ngini = 0.062\nsamples = 217\nvalue = [210, 7]\nclass = Reprovados'),
#  Text(0.4031284302963776, 0.6730769230769231, 'x[2] <= 38.318\ngini = 0.033\nsamples = 178\nvalue = [175, 3]\nclass = Reprovados'),
#  Text(0.3943468715697036, 0.6346153846153846, 'x[2] <= 38.129\ngini = 0.153\nsamples = 24\nvalue = [22, 2]\nclass = Reprovados'),
#  Text(0.3899560922063666, 0.5961538461538461, 'x[3] <= 1.384\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = Reprovados'),
#  Text(0.38556531284302964, 0.5576923076923077, 'x[0] <= 8784.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Reprovados'),
#  Text(0.38117453347969266, 0.5192307692307693, 'x[15] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.3767837541163557, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.38556531284302964, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.3899560922063666, 0.5192307692307693, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.3943468715697036, 0.5576923076923077, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Reprovados'),
#  Text(0.3987376509330406, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4119099890230516, 0.6346153846153846, 'x[0] <= 3893.5\ngini = 0.013\nsamples = 154\nvalue = [153, 1]\nclass = Reprovados'),
#  Text(0.4075192096597146, 0.5961538461538461, 'x[0] <= 3860.5\ngini = 0.044\nsamples = 44\nvalue = [43, 1]\nclass = Reprovados'),
#  Text(0.4031284302963776, 0.5576923076923077, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]\nclass = Reprovados'),
#  Text(0.4119099890230516, 0.5576923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4163007683863886, 0.5961538461538461, 'gini = 0.0\nsamples = 110\nvalue = [110, 0]\nclass = Reprovados'),
#  Text(0.4294731064763996, 0.6730769230769231, 'x[0] <= 13372.5\ngini = 0.184\nsamples = 39\nvalue = [35, 4]\nclass = Reprovados'),
#  Text(0.42508232711306254, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.43386388583973656, 0.6346153846153846, 'x[15] <= 0.5\ngini = 0.145\nsamples = 38\nvalue = [35, 3]\nclass = Reprovados'),
#  Text(0.42508232711306254, 0.5961538461538461, 'x[0] <= 13721.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]\nclass = Reprovados'),
#  Text(0.42069154774972556, 0.5576923076923077, 'x[0] <= 13720.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.4163007683863886, 0.5192307692307693, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.42508232711306254, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4294731064763996, 0.5576923076923077, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = Reprovados'),
#  Text(0.44264544456641053, 0.5961538461538461, 'x[8] <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Reprovados'),
#  Text(0.43825466520307355, 0.5576923076923077, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.4470362239297475, 0.5576923076923077, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.42508232711306254, 0.7115384615384616, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4294731064763996, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4470362239297475, 0.8269230769230769, 'x[8] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.44264544456641053, 0.7884615384615384, 'x[0] <= 3327.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.43825466520307355, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.4470362239297475, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.45142700329308455, 0.7884615384615384, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.8762113234083425, 0.9038461538461539, 'x[23] <= 0.5\ngini = 0.018\nsamples = 7308\nvalue = [7243, 65]\nclass = Reprovados'),
#  Text(0.7721811539517014, 0.8653846153846154, 'x[0] <= 15107.5\ngini = 0.017\nsamples = 7263\nvalue = [7201, 62]\nclass = Reprovados'),
#  Text(0.6206520993413831, 0.8269230769230769, 'x[8] <= 3.5\ngini = 0.015\nsamples = 6673\nvalue = [6621, 52]\nclass = Reprovados'),
#  Text(0.5046137486278814, 0.7884615384615384, 'x[0] <= 6078.5\ngini = 0.013\nsamples = 5884\nvalue = [5845, 39]\nclass = Reprovados'),
#  Text(0.47557628979143796, 0.75, 'x[21] <= 0.5\ngini = 0.006\nsamples = 2336\nvalue = [2329, 7]\nclass = Reprovados'),
#  Text(0.45581778265642153, 0.7115384615384616, 'x[2] <= 52.105\ngini = 0.002\nsamples = 1674\nvalue = [1672, 2]\nclass = Reprovados'),
#  Text(0.45142700329308455, 0.6730769230769231, 'gini = 0.0\nsamples = 1362\nvalue = [1362, 0]\nclass = Reprovados'),
#  Text(0.4602085620197585, 0.6730769230769231, 'x[2] <= 52.167\ngini = 0.013\nsamples = 312\nvalue = [310, 2]\nclass = Reprovados'),
#  Text(0.45581778265642153, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4645993413830955, 0.6346153846153846, 'x[0] <= 332.5\ngini = 0.006\nsamples = 311\nvalue = [310, 1]\nclass = Reprovados'),
#  Text(0.4602085620197585, 0.5961538461538461, 'x[0] <= 283.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]\nclass = Reprovados'),
#  Text(0.45581778265642153, 0.5576923076923077, 'gini = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = Reprovados'),
#  Text(0.4645993413830955, 0.5576923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4689901207464325, 0.5961538461538461, 'gini = 0.0\nsamples = 288\nvalue = [288, 0]\nclass = Reprovados'),
#  Text(0.49533479692645443, 0.7115384615384616, 'x[11] <= 0.5\ngini = 0.015\nsamples = 662\nvalue = [657, 5]\nclass = Reprovados'),
#  Text(0.49094401756311745, 0.6730769230769231, 'x[0] <= 4261.0\ngini = 0.034\nsamples = 291\nvalue = [286, 5]\nclass = Reprovados'),
#  Text(0.48655323819978047, 0.6346153846153846, 'x[0] <= 4259.5\ngini = 0.055\nsamples = 177\nvalue = [172, 5]\nclass = Reprovados'),
#  Text(0.4821624588364435, 0.5961538461538461, 'x[0] <= 4121.0\ngini = 0.044\nsamples = 176\nvalue = [172, 4]\nclass = Reprovados'),
#  Text(0.47338090010976946, 0.5576923076923077, 'x[0] <= 3013.0\ngini = 0.034\nsamples = 172\nvalue = [169, 3]\nclass = Reprovados'),
#  Text(0.4689901207464325, 0.5192307692307693, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]\nclass = Reprovados'),
#  Text(0.4777716794731065, 0.5192307692307693, 'x[0] <= 3014.5\ngini = 0.087\nsamples = 66\nvalue = [63, 3]\nclass = Reprovados'),
#  Text(0.47338090010976946, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4821624588364435, 0.4807692307692308, 'x[0] <= 3020.5\ngini = 0.06\nsamples = 65\nvalue = [63, 2]\nclass = Reprovados'),
#  Text(0.47338090010976946, 0.4423076923076923, 'x[0] <= 3019.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Reprovados'),
#  Text(0.4689901207464325, 0.40384615384615385, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.4777716794731065, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.49094401756311745, 0.4423076923076923, 'x[35] <= 0.5\ngini = 0.033\nsamples = 60\nvalue = [59, 1]\nclass = Reprovados'),
#  Text(0.48655323819978047, 0.40384615384615385, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]\nclass = Reprovados'),
#  Text(0.49533479692645443, 0.40384615384615385, 'x[0] <= 3121.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.49094401756311745, 0.36538461538461536, 'x[0] <= 3107.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.48655323819978047, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.49533479692645443, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.4997255762897914, 0.36538461538461536, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.49094401756311745, 0.5576923076923077, 'x[0] <= 4170.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.48655323819978047, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.49533479692645443, 0.5192307692307693, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.49094401756311745, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.49533479692645443, 0.6346153846153846, 'gini = 0.0\nsamples = 114\nvalue = [114, 0]\nclass = Reprovados'),
#  Text(0.4997255762897914, 0.6730769230769231, 'gini = 0.0\nsamples = 371\nvalue = [371, 0]\nclass = Reprovados'),
#  Text(0.5336512074643249, 0.75, 'x[0] <= 6080.5\ngini = 0.018\nsamples = 3548\nvalue = [3516, 32]\nclass = Reprovados'),
#  Text(0.529260428100988, 0.7115384615384616, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5380419868276619, 0.7115384615384616, 'x[0] <= 6084.0\ngini = 0.017\nsamples = 3547\nvalue = [3516, 31]\nclass = Reprovados'),
#  Text(0.5085071350164654, 0.6730769230769231, 'x[0] <= 6082.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.5041163556531284, 0.6346153846153846, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.5128979143798024, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5675768386388584, 0.6730769230769231, 'x[0] <= 6408.5\ngini = 0.017\nsamples = 3544\nvalue = [3514, 30]\nclass = Reprovados'),
#  Text(0.5216794731064764, 0.6346153846153846, 'x[0] <= 6403.5\ngini = 0.077\nsamples = 149\nvalue = [143, 6]\nclass = Reprovados'),
#  Text(0.5172886937431395, 0.5961538461538461, 'x[28] <= 0.5\ngini = 0.04\nsamples = 146\nvalue = [143, 3]\nclass = Reprovados'),
#  Text(0.5128979143798024, 0.5576923076923077, 'gini = 0.0\nsamples = 129\nvalue = [129, 0]\nclass = Reprovados'),
#  Text(0.5216794731064764, 0.5576923076923077, 'x[0] <= 6388.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]\nclass = Reprovados'),
#  Text(0.5172886937431395, 0.5192307692307693, 'x[3] <= 4.29\ngini = 0.219\nsamples = 16\nvalue = [14, 2]\nclass = Reprovados'),
#  Text(0.5128979143798024, 0.4807692307692308, 'x[0] <= 6155.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Reprovados'),
#  Text(0.5085071350164654, 0.4423076923076923, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.5172886937431395, 0.4423076923076923, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.5216794731064764, 0.4807692307692308, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Reprovados'),
#  Text(0.5260702524698134, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5260702524698134, 0.5961538461538461, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Aprovados'),
#  Text(0.6134742041712404, 0.6346153846153846, 'x[14] <= 0.5\ngini = 0.014\nsamples = 3395\nvalue = [3371, 24]\nclass = Reprovados'),
#  Text(0.5546103183315039, 0.5961538461538461, 'x[10] <= 0.5\ngini = 0.024\nsamples = 1253\nvalue = [1238, 15]\nclass = Reprovados'),
#  Text(0.5436333699231614, 0.5576923076923077, 'x[2] <= 26.064\ngini = 0.033\nsamples = 825\nvalue = [811, 14]\nclass = Reprovados'),
#  Text(0.5348518111964874, 0.5192307692307693, 'x[0] <= 7435.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.5304610318331504, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5392425905598244, 0.4807692307692308, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.5524149286498353, 0.5192307692307693, 'x[12] <= 0.5\ngini = 0.031\nsamples = 819\nvalue = [806, 13]\nclass = Reprovados'),
#  Text(0.5480241492864983, 0.4807692307692308, 'x[0] <= 6603.0\ngini = 0.044\nsamples = 573\nvalue = [560, 13]\nclass = Reprovados'),
#  Text(0.5290889132821076, 0.4423076923076923, 'x[0] <= 6580.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Reprovados'),
#  Text(0.5246981339187706, 0.40384615384615385, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.5334796926454446, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5669593852908892, 0.4423076923076923, 'x[2] <= 53.963\ngini = 0.042\nsamples = 565\nvalue = [553, 12]\nclass = Reprovados'),
#  Text(0.5422612513721186, 0.40384615384615385, 'x[0] <= 14044.0\ngini = 0.032\nsamples = 488\nvalue = [480, 8]\nclass = Reprovados'),
#  Text(0.5214050493962679, 0.36538461538461536, 'x[0] <= 9506.5\ngini = 0.019\nsamples = 415\nvalue = [411, 4]\nclass = Reprovados'),
#  Text(0.5104281009879253, 0.3269230769230769, 'x[0] <= 9501.0\ngini = 0.045\nsamples = 129\nvalue = [126, 3]\nclass = Reprovados'),
#  Text(0.5060373216245884, 0.28846153846153844, 'x[25] <= 0.5\ngini = 0.031\nsamples = 128\nvalue = [126, 2]\nclass = Reprovados'),
#  Text(0.4972557628979144, 0.25, 'x[27] <= 0.5\ngini = 0.017\nsamples = 115\nvalue = [114, 1]\nclass = Reprovados'),
#  Text(0.49286498353457736, 0.21153846153846154, 'gini = 0.0\nsamples = 93\nvalue = [93, 0]\nclass = Reprovados'),
#  Text(0.5016465422612514, 0.21153846153846154, 'x[0] <= 7872.5\ngini = 0.087\nsamples = 22\nvalue = [21, 1]\nclass = Reprovados'),
#  Text(0.4972557628979144, 0.17307692307692307, 'x[0] <= 7526.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Reprovados'),
#  Text(0.49286498353457736, 0.1346153846153846, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.5016465422612514, 0.1346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5060373216245884, 0.17307692307692307, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Reprovados'),
#  Text(0.5148188803512623, 0.25, 'x[2] <= 44.553\ngini = 0.142\nsamples = 13\nvalue = [12, 1]\nclass = Reprovados'),
#  Text(0.5104281009879253, 0.21153846153846154, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]\nclass = Reprovados'),
#  Text(0.5192096597145993, 0.21153846153846154, 'x[2] <= 50.793\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.5148188803512623, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5236004390779363, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.5148188803512623, 0.28846153846153844, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5323819978046103, 0.3269230769230769, 'x[3] <= 18.347\ngini = 0.007\nsamples = 286\nvalue = [285, 1]\nclass = Reprovados'),
#  Text(0.5279912184412733, 0.28846153846153844, 'gini = 0.0\nsamples = 241\nvalue = [241, 0]\nclass = Reprovados'),
#  Text(0.5367727771679474, 0.28846153846153844, 'x[3] <= 18.615\ngini = 0.043\nsamples = 45\nvalue = [44, 1]\nclass = Reprovados'),
#  Text(0.5323819978046103, 0.25, 'x[0] <= 11669.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.5279912184412733, 0.21153846153846154, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5367727771679474, 0.21153846153846154, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.5411635565312843, 0.25, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]\nclass = Reprovados'),
#  Text(0.5631174533479693, 0.36538461538461536, 'x[0] <= 14102.0\ngini = 0.104\nsamples = 73\nvalue = [69, 4]\nclass = Reprovados'),
#  Text(0.5587266739846323, 0.3269230769230769, 'x[0] <= 14096.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]\nclass = Reprovados'),
#  Text(0.5543358946212953, 0.28846153846153844, 'x[0] <= 14046.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = Reprovados'),
#  Text(0.5499451152579583, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5587266739846323, 0.25, 'x[25] <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Reprovados'),
#  Text(0.5543358946212953, 0.21153846153846154, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = Reprovados'),
#  Text(0.5631174533479693, 0.21153846153846154, 'x[0] <= 14079.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.5587266739846323, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.5675082327113062, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.5631174533479693, 0.28846153846153844, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.5675082327113062, 0.3269230769230769, 'gini = 0.0\nsamples = 59\nvalue = [59, 0]\nclass = Reprovados'),
#  Text(0.5916575192096597, 0.40384615384615385, 'x[2] <= 54.033\ngini = 0.098\nsamples = 77\nvalue = [73, 4]\nclass = Reprovados'),
#  Text(0.5806805708013172, 0.36538461538461536, 'x[0] <= 10326.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Reprovados'),
#  Text(0.5762897914379802, 0.3269230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.5850713501646543, 0.3269230769230769, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.6026344676180022, 0.36538461538461536, 'x[0] <= 8173.0\ngini = 0.055\nsamples = 71\nvalue = [69, 2]\nclass = Reprovados'),
#  Text(0.5938529088913282, 0.3269230769230769, 'x[0] <= 7981.0\ngini = 0.165\nsamples = 11\nvalue = [10, 1]\nclass = Reprovados'),
#  Text(0.5894621295279913, 0.28846153846153844, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Reprovados'),
#  Text(0.5982436882546652, 0.28846153846153844, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.6114160263446762, 0.3269230769230769, 'x[3] <= 6.421\ngini = 0.033\nsamples = 60\nvalue = [59, 1]\nclass = Reprovados'),
#  Text(0.6070252469813392, 0.28846153846153844, 'x[3] <= 6.322\ngini = 0.111\nsamples = 17\nvalue = [16, 1]\nclass = Reprovados'),
#  Text(0.6026344676180022, 0.25, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Reprovados'),
#  Text(0.6114160263446762, 0.25, 'x[0] <= 10395.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.6070252469813392, 0.21153846153846154, 'x[0] <= 10394.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.6026344676180022, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.6114160263446762, 0.17307692307692307, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.6158068057080132, 0.21153846153846154, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Reprovados'),
#  Text(0.6158068057080132, 0.28846153846153844, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]\nclass = Reprovados'),
#  Text(0.5568057080131723, 0.4807692307692308, 'gini = 0.0\nsamples = 246\nvalue = [246, 0]\nclass = Reprovados'),
#  Text(0.5655872667398463, 0.5576923076923077, 'x[0] <= 14918.0\ngini = 0.005\nsamples = 428\nvalue = [427, 1]\nclass = Reprovados'),
# ...
#  Text(0.6926454445664105, 0.5192307692307693, 'x[3] <= 3.377\ngini = 0.029\nsamples = 68\nvalue = [67, 1]\nclass = Reprovados'),
#  Text(0.6882546652030735, 0.4807692307692308, 'gini = 0.0\nsamples = 62\nvalue = [62, 0]\nclass = Reprovados'),
#  Text(0.6970362239297475, 0.4807692307692308, 'x[0] <= 10399.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.6926454445664105, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7014270032930845, 0.4423076923076923, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.7102085620197585, 0.5192307692307693, 'x[7] <= 0.5\ngini = 0.002\nsamples = 1294\nvalue = [1293, 1]\nclass = Reprovados'),
#  Text(0.7058177826564215, 0.4807692307692308, 'gini = 0.0\nsamples = 1162\nvalue = [1162, 0]\nclass = Reprovados'),
#  Text(0.7145993413830956, 0.4807692307692308, 'x[0] <= 12296.0\ngini = 0.015\nsamples = 132\nvalue = [131, 1]\nclass = Reprovados'),
#  Text(0.7102085620197585, 0.4423076923076923, 'gini = 0.0\nsamples = 111\nvalue = [111, 0]\nclass = Reprovados'),
#  Text(0.7189901207464325, 0.4423076923076923, 'x[0] <= 12389.0\ngini = 0.091\nsamples = 21\nvalue = [20, 1]\nclass = Reprovados'),
#  Text(0.7145993413830956, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7233809001097695, 0.40384615384615385, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]\nclass = Reprovados'),
#  Text(0.7366904500548848, 0.7884615384615384, 'x[0] <= 1752.5\ngini = 0.032\nsamples = 789\nvalue = [776, 13]\nclass = Reprovados'),
#  Text(0.712403951701427, 0.75, 'x[0] <= 1750.0\ngini = 0.119\nsamples = 79\nvalue = [74, 5]\nclass = Reprovados'),
#  Text(0.70801317233809, 0.7115384615384616, 'x[2] <= 29.736\ngini = 0.075\nsamples = 77\nvalue = [74, 3]\nclass = Reprovados'),
#  Text(0.6926454445664105, 0.6730769230769231, 'x[0] <= 312.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.6882546652030735, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.6970362239297475, 0.6346153846153846, 'x[0] <= 393.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.6926454445664105, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7014270032930845, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.7233809001097695, 0.6730769230769231, 'x[0] <= 1620.0\ngini = 0.053\nsamples = 74\nvalue = [72, 2]\nclass = Reprovados'),
#  Text(0.7145993413830956, 0.6346153846153846, 'x[13] <= 0.5\ngini = 0.029\nsamples = 67\nvalue = [66, 1]\nclass = Reprovados'),
#  Text(0.7102085620197585, 0.5961538461538461, 'gini = 0.0\nsamples = 58\nvalue = [58, 0]\nclass = Reprovados'),
#  Text(0.7189901207464325, 0.5961538461538461, 'x[9] <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Reprovados'),
#  Text(0.7145993413830956, 0.5576923076923077, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.7233809001097695, 0.5576923076923077, 'x[0] <= 626.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.7189901207464325, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.7277716794731065, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7321624588364435, 0.6346153846153846, 'x[3] <= 11.277\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Reprovados'),
#  Text(0.7277716794731065, 0.5961538461538461, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Reprovados'),
#  Text(0.7365532381997805, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.716794731064764, 0.7115384615384616, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.7609769484083425, 0.75, 'x[3] <= 5.888\ngini = 0.022\nsamples = 710\nvalue = [702, 8]\nclass = Reprovados'),
#  Text(0.7565861690450055, 0.7115384615384616, 'gini = 0.0\nsamples = 204\nvalue = [204, 0]\nclass = Reprovados'),
#  Text(0.7653677277716795, 0.7115384615384616, 'x[3] <= 5.942\ngini = 0.031\nsamples = 506\nvalue = [498, 8]\nclass = Reprovados'),
#  Text(0.7609769484083425, 0.6730769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7697585071350165, 0.6730769230769231, 'x[3] <= 6.056\ngini = 0.027\nsamples = 505\nvalue = [498, 7]\nclass = Reprovados'),
#  Text(0.7497255762897914, 0.6346153846153846, 'x[0] <= 4460.5\ngini = 0.172\nsamples = 21\nvalue = [19, 2]\nclass = Reprovados'),
#  Text(0.7453347969264544, 0.5961538461538461, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7541163556531284, 0.5961538461538461, 'x[12] <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [19, 1]\nclass = Reprovados'),
#  Text(0.7497255762897914, 0.5576923076923077, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = Reprovados'),
#  Text(0.7585071350164654, 0.5576923076923077, 'x[0] <= 11153.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = Reprovados'),
#  Text(0.7541163556531284, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7628979143798024, 0.5192307692307693, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Reprovados'),
#  Text(0.7897914379802415, 0.6346153846153846, 'x[3] <= 11.832\ngini = 0.02\nsamples = 484\nvalue = [479, 5]\nclass = Reprovados'),
#  Text(0.7716794731064764, 0.5961538461538461, 'x[8] <= 4.5\ngini = 0.006\nsamples = 313\nvalue = [312, 1]\nclass = Reprovados'),
#  Text(0.7672886937431395, 0.5576923076923077, 'gini = 0.0\nsamples = 276\nvalue = [276, 0]\nclass = Reprovados'),
#  Text(0.7760702524698134, 0.5576923076923077, 'x[0] <= 6745.5\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = Reprovados'),
#  Text(0.7716794731064764, 0.5192307692307693, 'x[0] <= 6729.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Reprovados'),
#  Text(0.7672886937431395, 0.4807692307692308, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Reprovados'),
#  Text(0.7760702524698134, 0.4807692307692308, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7804610318331504, 0.5192307692307693, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = Reprovados'),
#  Text(0.8079034028540066, 0.5961538461538461, 'x[3] <= 11.953\ngini = 0.046\nsamples = 171\nvalue = [167, 4]\nclass = Reprovados'),
#  Text(0.7936333699231614, 0.5576923076923077, 'x[0] <= 13518.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.7892425905598244, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.7980241492864983, 0.5192307692307693, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.8221734357848518, 0.5576923076923077, 'x[5] <= 0.5\ngini = 0.035\nsamples = 169\nvalue = [166, 3]\nclass = Reprovados'),
#  Text(0.8068057080131723, 0.5192307692307693, 'x[21] <= 0.5\ngini = 0.015\nsamples = 130\nvalue = [129, 1]\nclass = Reprovados'),
#  Text(0.8024149286498353, 0.4807692307692308, 'gini = 0.0\nsamples = 82\nvalue = [82, 0]\nclass = Reprovados'),
#  Text(0.8111964873765093, 0.4807692307692308, 'x[3] <= 15.548\ngini = 0.041\nsamples = 48\nvalue = [47, 1]\nclass = Reprovados'),
#  Text(0.8068057080131723, 0.4423076923076923, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = Reprovados'),
#  Text(0.8155872667398463, 0.4423076923076923, 'x[3] <= 15.974\ngini = 0.111\nsamples = 17\nvalue = [16, 1]\nclass = Reprovados'),
#  Text(0.8111964873765093, 0.40384615384615385, 'x[0] <= 8582.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Reprovados'),
#  Text(0.8068057080131723, 0.36538461538461536, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.8155872667398463, 0.36538461538461536, 'x[0] <= 8583.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.8111964873765093, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8199780461031834, 0.3269230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.8199780461031834, 0.40384615384615385, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = Reprovados'),
#  Text(0.8375411635565313, 0.5192307692307693, 'x[2] <= 33.73\ngini = 0.097\nsamples = 39\nvalue = [37, 2]\nclass = Reprovados'),
#  Text(0.8287596048298573, 0.4807692307692308, 'x[0] <= 10425.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.8243688254665203, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8331503841931943, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.8463227222832053, 0.4807692307692308, 'x[0] <= 4490.5\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = Reprovados'),
#  Text(0.8419319429198683, 0.4423076923076923, 'x[0] <= 4489.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.8375411635565313, 0.40384615384615385, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Reprovados'),
#  Text(0.8463227222832053, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8507135016465422, 0.4423076923076923, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = Reprovados'),
#  Text(0.9237102085620198, 0.8269230769230769, 'x[0] <= 15114.5\ngini = 0.033\nsamples = 590\nvalue = [580, 10]\nclass = Reprovados'),
#  Text(0.9193194291986828, 0.7884615384615384, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9281009879253568, 0.7884615384615384, 'x[33] <= 0.5\ngini = 0.03\nsamples = 589\nvalue = [580, 9]\nclass = Reprovados'),
#  Text(0.9088913282107574, 0.75, 'x[3] <= 33.396\ngini = 0.024\nsamples = 580\nvalue = [573, 7]\nclass = Reprovados'),
#  Text(0.8924259055982436, 0.7115384615384616, 'x[3] <= 4.753\ngini = 0.021\nsamples = 572\nvalue = [566, 6]\nclass = Reprovados'),
#  Text(0.8814489571899012, 0.6730769230769231, 'x[3] <= 4.67\ngini = 0.068\nsamples = 141\nvalue = [136, 5]\nclass = Reprovados'),
#  Text(0.8726673984632273, 0.6346153846153846, 'x[2] <= 34.899\ngini = 0.044\nsamples = 132\nvalue = [129, 3]\nclass = Reprovados'),
#  Text(0.8682766190998902, 0.5961538461538461, 'x[2] <= 34.474\ngini = 0.115\nsamples = 49\nvalue = [46, 3]\nclass = Reprovados'),
#  Text(0.8638858397365532, 0.5576923076923077, 'x[0] <= 15883.5\ngini = 0.08\nsamples = 48\nvalue = [46, 2]\nclass = Reprovados'),
#  Text(0.8594950603732162, 0.5192307692307693, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]\nclass = Reprovados'),
#  Text(0.8682766190998902, 0.5192307692307693, 'x[0] <= 15957.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]\nclass = Reprovados'),
#  Text(0.8638858397365532, 0.4807692307692308, 'x[9] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Aprovados'),
#  Text(0.8594950603732162, 0.4423076923076923, 'x[0] <= 15884.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.8551042810098792, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8638858397365532, 0.40384615384615385, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.8682766190998902, 0.4423076923076923, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8726673984632273, 0.4807692307692308, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Reprovados'),
#  Text(0.8726673984632273, 0.5576923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.8770581778265643, 0.5961538461538461, 'gini = 0.0\nsamples = 83\nvalue = [83, 0]\nclass = Reprovados'),
#  Text(0.8902305159165752, 0.6346153846153846, 'x[2] <= 47.326\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Reprovados'),
#  Text(0.8858397365532382, 0.5961538461538461, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Reprovados'),
#  Text(0.8946212952799122, 0.5961538461538461, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Aprovados'),
#  Text(0.9034028540065862, 0.6730769230769231, 'x[28] <= 0.5\ngini = 0.005\nsamples = 431\nvalue = [430, 1]\nclass = Reprovados'),
#  Text(0.8990120746432492, 0.6346153846153846, 'gini = 0.0\nsamples = 378\nvalue = [378, 0]\nclass = Reprovados'),
#  Text(0.9077936333699231, 0.6346153846153846, 'x[13] <= 0.5\ngini = 0.037\nsamples = 53\nvalue = [52, 1]\nclass = Reprovados'),
#  Text(0.9034028540065862, 0.5961538461538461, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]\nclass = Reprovados'),
#  Text(0.9121844127332601, 0.5961538461538461, 'x[0] <= 15475.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]\nclass = Reprovados'),
#  Text(0.9077936333699231, 0.5576923076923077, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = Reprovados'),
#  Text(0.9165751920965971, 0.5576923076923077, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9253567508232712, 0.7115384615384616, 'x[3] <= 35.519\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Reprovados'),
#  Text(0.9209659714599341, 0.6730769230769231, 'x[0] <= 15438.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.9165751920965971, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.9253567508232712, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9297475301866082, 0.6730769230769231, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Reprovados'),
#  Text(0.9473106476399561, 0.75, 'x[1] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Reprovados'),
#  Text(0.9429198682766191, 0.7115384615384616, 'x[10] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Aprovados'),
#  Text(0.9385290889132821, 0.6730769230769231, 'x[0] <= 15195.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.9341383095499451, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9429198682766191, 0.6346153846153846, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.9473106476399561, 0.6730769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9517014270032931, 0.7115384615384616, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Reprovados'),
#  Text(0.9802414928649835, 0.8653846153846154, 'x[3] <= 16.804\ngini = 0.124\nsamples = 45\nvalue = [42, 3]\nclass = Reprovados'),
#  Text(0.969264544456641, 0.8269230769230769, 'x[2] <= 27.182\ngini = 0.089\nsamples = 43\nvalue = [41, 2]\nclass = Reprovados'),
#  Text(0.960482985729967, 0.7884615384615384, 'x[0] <= 13147.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.9560922063666301, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.964873765093304, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9780461031833151, 0.7884615384615384, 'x[2] <= 29.481\ngini = 0.048\nsamples = 41\nvalue = [40, 1]\nclass = Reprovados'),
#  Text(0.973655323819978, 0.75, 'x[0] <= 5137.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = Reprovados'),
#  Text(0.969264544456641, 0.7115384615384616, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Reprovados'),
#  Text(0.9780461031833151, 0.7115384615384616, 'x[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.973655323819978, 0.6730769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.9824368825466521, 0.6730769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.9824368825466521, 0.75, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]\nclass = Reprovados'),
#  Text(0.991218441273326, 0.8269230769230769, 'x[3] <= 23.768\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Reprovados'),
#  Text(0.986827661909989, 0.7884615384615384, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Aprovados'),
#  Text(0.995609220636663, 0.7884615384615384, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Reprovados'),
#  Text(0.5787778282793633, 0.9423076923076923, 'gini = 0.0\nsamples = 125\nvalue = [0, 125]\nclass = Aprovados')]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#4
predict_test = clf.predict(X_test)
cm = confusion_matrix(y_test, predict_test)

cm_plot = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

cm_plot.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#5
accuracy_score(y_test, predict_test)
# Out:
# 0.978978978978979

# %% [markdown]
# #### 3) Vamos avaliar o modelo na base de testes
#
# 1. Classifique a base de teste de acordo com a árvore que você treinou no item 2.
# 2. Produza a visualização da matriz de confusão para a base de teste.
# 3. Calcule a acurácia da base de teste. Compare com a acurácia da base de treinamento.
# 4. Treine uma nova árvore com número mínimo de observações por folha de 5 e máximo de profundidade de 10. Use o random_state = 123. Avalie a matriz de classificação. Observe a distribuição da predição - qual a proporção de proponentes foram classificados como 'maus'?
# 5. Como ficaria a acurácia se você classificasse todos os contratos como 'bons'?

# %%
y_pred_train = clf.predict(X_train)

cm = confusion_matrix(y_train, y_pred_train)

cm_plot = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Aprovados', 'Reprovados'])

cm_plot.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
clf_novo = DecisionTreeClassifier(min_samples_leaf=5, max_depth=10, random_state=123)
clf_novo.fit(X_train, y_train)

y_pred_test_novo= clf_novo.predict(X_test)
confusion_matrix(y_test, y_pred_test_novo)

proportion_maus = sum(y_pred_test_novo == 'mau') / len(y_pred_test_novo)
print(proportion_maus)
# Out:
# 0.0
