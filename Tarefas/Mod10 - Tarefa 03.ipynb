# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

df = pd.read_csv('previsao_de_renda.csv',parse_dates=[0])
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
# C:\Users\thomas.costa\AppData\Local\Temp\ipykernel_29720\4245133666.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('previsao_de_renda.csv',parse_dates=[0])
#          data_ref  index sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0      2015-01-01   8682    F             False             True           1
# 1      2015-01-01  12830    M              True             True           0
# 2      2015-01-01   2885    M              True             True           2
# 3      2015-01-01  16168    F              True            False           0
# 4      2015-01-01  12438    M             False            False           0
# ...           ...    ...  ...               ...              ...         ...
# 14995  2016-03-01   3678    M              True             True           1
# 14996  2016-03-01   3405    M              True             True           1
# 14997  2016-03-01   7944    F              True             True           0
# 14998  2016-03-01  16019    F             False             True           0
# 14999  2016-03-01  12895    F              True             True           0
#
#              tipo_renda           educacao estado_civil tipo_residencia  \
# 0           Assalariado         Secundário       Casado            Casa
# 1            Empresário         Secundário       Casado            Casa
# 2           Assalariado  Superior completo       Casado            Casa
# 3            Empresário         Secundário       Casado            Casa
# 4           Assalariado         Secundário       Casado            Casa
# ...                 ...                ...          ...             ...
# 14995       Assalariado         Secundário       Casado            Casa
# 14996  Servidor público  Superior completo       Casado         Estúdio
# 14997       Assalariado         Secundário       Casado            Casa
# 14998  Servidor público  Superior completo       Casado            Casa
# 14999       Assalariado         Secundário       Casado            Casa
#
#        idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# 0         36       3.575342                    3.0  False  3369.24
# 1         42       0.860274                    2.0  False  6096.14
# 2         31       8.065753                    4.0  False  5658.98
# 3         50       1.208219                    2.0  False  7246.69
# 4         52      13.873973                    2.0  False  4017.37
# ...      ...            ...                    ...    ...      ...
# 14995     37       2.046575                    3.0  False  1193.29
# 14996     30      12.079452                    3.0  False  2519.18
# 14997     40       2.161644                    2.0  False  1586.85
# 14998     47       3.295890                    2.0  False  6975.39
# 14999     50       3.049315                    2.0  False   993.86
#
# [15000 rows x 15 columns]

# %%
variaveis_qualitativas = ['sexo', 'tipo_residencia', 'estado_civil', 'tipo_renda','educacao']
#converte a coluna data_ref em datetime
df['data_ref'] = pd.to_datetime(df['data_ref'])

# Definir o número de linhas e colunas para o grid
num_linhas = len(variaveis_qualitativas)
num_colunas = 1  # Uma coluna para o tempo
# Criar a figura e os subplots
fig, axs = plt.subplots(num_linhas, num_colunas, figsize=(10, 3 * num_linhas))
fig.tight_layout(pad=6.0)

for i, variavel in enumerate(variaveis_qualitativas):
    ax = sns.countplot(x='data_ref', hue=variavel,data=df, ax=axs[i])
    #retorna as data em tempo unicos para a geração do gráfico
    ticks_labels = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

    ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
    labels = ax.set_xticklabels(ticks_labels, rotation=45)

    # Adicionar legenda fora do gráfico
    ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set_xlabel('Data de Referência')
    ax.set_ylabel('Contagem')
    ax.set_title(f'Distribuição de {variavel} ao Longo do Tempo')
    # Adicionar legenda fora do gráfico
    ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
import matplotlib.dates as mdates

variaveis_qualitativas = ['sexo', 'tipo_residencia', 'estado_civil', 'tipo_renda','educacao']
#converte a coluna data_ref em datetime

# Definir o número de linhas e colunas para o grid
num_linhas = len(variaveis_qualitativas)
num_colunas = 1  # Uma coluna para o tempo
# Criar a figura e os subplots
fig, axs = plt.subplots(num_linhas, num_colunas, figsize=(10, 3 * num_linhas))
fig.tight_layout(pad=6.0)

for i, variavel in enumerate(variaveis_qualitativas):
    #ax = sns.countplot(x='data_ref', hue=variavel, data=df, ax=axs[i])
    #retorna as data em tempo unicos para a geração do gráfico
    ticks_labels = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

    ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
    labels = ax.set_xticklabels(ticks_labels, rotation=45)

    # Adicionar legenda fora do gráfico
    ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set_xlabel('Data de Referência')
    ax.set_ylabel('Contagem')
    ax.set_title(f'Distribuição de {variavel} ao Longo do Tempo')
    axb = ax.twinx()
    axb = sns.pointplot(x='data_ref', y=variavel, data=df, dodge=True, errorbar=('ci', 90), color = 'navy')
    # Adicionar legenda fora do gráfico
    ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[5], line 27
#      25 ax.set_title(f'Distribuição de {variavel} ao Longo do Tempo')
#      26 axb = ax.twinx()
# ---> 27 axb = sns.pointplot(x='data_ref', y=variavel, data=df, dodge=True, errorbar=('ci', 90), color = 'navy')
#      28 # Adicionar legenda fora do gráfico
#      29 ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\seaborn\categorical.py:2839, in pointplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, ci, capsize, label, ax)
#    2829 def pointplot(
#    2830     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2831     estimator="mean", errorbar=("ci", 95), n_boot=1000, units=None, seed=None,
#    (...)
#    2834     capsize=None, label=None, ax=None,
#    2835 ):
#    2837     errorbar = utils._deprecate_ci(errorbar, ci)
# -> 2839     plotter = _PointPlotter(x, y, hue, data, order, hue_order,
#    2840                             estimator, errorbar, n_boot, units, seed,
#    2841                             markers, linestyles, dodge, join, scale,
#    2842                             orient, color, palette, errwidth, capsize, label)
#    2844     if ax is None:
#    2845         ax = plt.gca()
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\seaborn\categorical.py:1604, in _PointPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, label)
#    1601 self.establish_variables(x, y, hue, data, orient,
#    1602                          order, hue_order, units)
#    1603 self.establish_colors(color, palette, 1)
# -> 1604 self.estimate_statistic(estimator, errorbar, n_boot, seed)
#    1606 # Override the default palette for single-color plots
#    1607 if hue is None and color is None and palette is None:
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\seaborn\categorical.py:1461, in _CategoricalStatPlotter.estimate_statistic(self, estimator, errorbar, n_boot, seed)
#    1458 if self.plot_units is not None:
#    1459     df["units"] = self.plot_units[i]
# -> 1461 res = agg(df, var)
#    1463 statistic.append(res[var])
#    1464 if errorbar is not None:
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\seaborn\_statistics.py:513, in EstimateAggregator.__call__(self, data, var)
#     511 elif self.error_method == "ci":
#     512     units = data.get("units", None)
# --> 513     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
#     514     err_min, err_max = _percentile_interval(boots, self.error_level)
#     516 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\seaborn\algorithms.py:70, in bootstrap(*args, **kwargs)
#      67 f = getattr(np, func)
#      69 # Try to use nan-aware version of function if necessary
# ---> 70 missing_data = np.isnan(np.sum(np.column_stack(args)))
#      72 if missing_data and not func.startswith("nan"):
#      73     nanf = getattr(np, f"nan{func}", None)
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\numpy\core\fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File c:\Users\thomas.costa\ebac\datascience-ebac\.venv\lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# UFuncTypeError: ufunc 'add' cannot use operands with types dtype('<M8[ns]') and dtype('<M8[ns]')
